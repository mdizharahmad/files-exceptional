# %% [markdown]
# **Files, exceptional handling ASSIGNMENT**

# %%
""" Q1. What is the difference between interpreted and compiled languages?
ANS,,
    1. Compiled Languages
    Your code is translated all at once by a compiler into machine code (binary).
   This machine code can be run directly by the computer’s processor.
    After compiling, you get an executable file (like .exe on Windows).
     Usually faster performance once compiled.

2. Interpreted Languages.
    Code is run line by line by an interpreter at runtime.
     No separate executable is created; you need the interpreter to run the code.
      Easier and faster to test changes (no need to compile).
       Great for scripting, automation, or quick prototyping.
       Cross-platform (as long as the interpreter exists for the system).

Q2. What is exception handling in Python,

ANS.
    Exception handling in Python is a way to deal with errors that occur during program execution—without crashing your whole program.



Q3.  What is the purpose of the finally block in exception handling
ANS
     Great follow-up! The finally block in Python’s exception handling is used to define
     cleanup actions that must happen no matter what—whether an exception occurred or not.

                Purpose of the finally block
            Ensures that important cleanup code runs, like:

           1.Closing a file
           2.Releasing resources
           3. Disconnecting from a database
           4. Stopping background processes
           5. It runs no matter what happens in the try or except blocks—even if there’s an error or a return statement.


Q4.  What is logging in Python
ans.
  Logging in Python is a way to record messages that describe,
    what your program is doing—especially useful for debugging,
   monitoring, or keeping a history of events in your application.



Q5. What is the significance of the __del__ method in Python.
ANS.

  The __del__ method in Python is a special method known as a destructor.
  It gets called when an object is about to be destroyed,
  i.e., when Python's garbage collector determines that the object is no longer in use.


Q6. What is the difference between import and from ... import in Python
ANS.
   In Python, both import and from ... import are used to bring external modules and their functionalities into your code,
    but they are used in slightly different ways and have distinct purposes.

    1.import
     When you use import, you’re bringing in the whole module into your code, and you’ ll access the functions,
     classes, or variables in that module using the module name.

  2. from ... import
      When you use from ... import, you're importing specific parts (functions, classes, variables)
       of a module directly into your namespace.
       This means you can use the imported items without the module name prefix.

# %%
#SYNTAX OF IMPORT
from module_name import item_name
#EXAMPLES:

from math import sqrt

print(sqrt(16))  # Directly use sqrt, no need for math.sqrt

#EXAMPLE:OF FROM...IMPORT
from math import

print(sqrt(16))  # Direct access to sqrt

# %%
'''
Q7. How can you handle multiple exceptions in Python
ANS.
   In Python, you can handle multiple exceptions in a few different ways depending
   on how you want to manage them. Python provides flexibility to catch multiple exceptions using multiple except blocks,
   a single except block with a tuple, or even handling them in the same except block.

Q8. What is the purpose of the with statement when handling files in Python
ANS.
   The with statement in Python is used to simplify resource management,
   especially when working with files. Its main purpose is to ensure that resources are properly
   cleaned up—like closing a file—even if an error occurs during the file operation.

    Why use with for files?
    When you open a file using the regular open() function,
     you’re responsible for closing it using file.close().
     If you forget to close it—or if an error occurs before you close it—the file can stay open, which may lead to:

    A. Memory leaks
    B.File locks
    C. Corrupted data

Q9. What is the difference between multithreading and multiprocessing
ANS.
    1. Multithreading
     Multithreading allows multiple threads (smaller units of a process) to run concurrently within the same process.
         In Python, threads are useful for I/O-bound tasks,
         like handling files, network requests, or user input, where the program spends time waiting for data
    2. Multiprocessing
     Multiprocessing uses separate processes, each with its own memory space.
     This allows for true parallelism and can fully utilize multiple CPU cores.
      Multiprocessing is ideal for CPU-bound tasks (tasks that require heavy computation).

Q10.  What are the advantages of using logging in a program.

ANS.
 Using logging in a program—especially beyond just print() statements—comes with a lot of practical benefits,
 especially as your project grows in size or complexity.


Q11.What is memory management in Python.
ANS.
    Memory management in Python refers to how Python allocates,
    uses, and releases memory while your program is running.
    It's an essential part of how Python runs efficiently,
    even though you usually don’t have to manage memory manually (like in C or C++).

      1 Key Concepts of Memory Management in Python
        Automatic Memory Management
        Python handles memory allocation and deallocation automatically. When you create variables,
        objects, or data structures (like lists or dictionaries), Python allocates memory behind the scen
        You don’t have to use malloc() or free() like in C—Python does this for you.

Q12. What are the basic steps involved in exception handling in Python .
ANS.
   Awesome question! In Python, exception handling is the process of
   responding to errors (called exceptions) that occur while a program is running.
   It helps prevent crashes and allows your program to deal with issues gracefully.

Q13.Why is memory management important in Python.
ANS.
   Memory management is important in Python (and any programming language) for several.
   Reasons — especially to ensure your programs run efficiently,
   don’t crash unexpectedly,
   and don’t waste system resources. Here’s a breakdown of why it matters in Python specifically:

Q14. What is the role of try and except in exception handling
ANS.

  Great question! The try and except blocks are core parts of Python’s exception handling system.
  They help your code deal with unexpected errors gracefully, instead of crashing your whole program.
   Here’s the role of each,

  1. try Block – "Attempt Something Risky"
  2. You put code that might raise an exception inside a try block.
  3. Python runs this code and watches for errors.
  4. If no error occurs, the except block is skipped.

Q15. How does Python's garbage collection system work.
ANS.
    Python’s garbage collection system is how it automatically manages memory,
    cleaning up objects that are no longer needed so you don’t have to do it manually (like in C or C++).
    It helps prevent memory leaks and keeps your program from using up too much RAM

      1. Reference Counting (The Core Mechanism)
    At the heart of Python’s memory management is reference counting.
   Every object in Python keeps track of how many references point to it.
   When you create a variable pointing to an object, its reference count goes up.
  When a reference is deleted (e.g., when a variable goes out of scope or is reassigned), the count goes down.

Q16.What is the purpose of the else block in exception handling
ANS.
Great question! The else block in Python's exception handling is used for code that should run only if no exceptions were raised in the try block.

 Purpose of the else block.
It helps separate
The code that might raise an exception (try)
The code that handles errors (except)
And the code that should run only if everything went well (else)

Q17.What are the common logging levels in Python
ANS.
In Python’s logging module, logging levels represent the severity of an event.
These levels help you filter and prioritize log messages depending on the situation (e.g., development, testing, or production).

Q18. What is the difference between os.fork() and multiprocessing in Python.
ANS.
Great question! Both os.fork() and the multiprocessing module in Python are used to create new processes,
but they differ in complexity, portability, and abstraction. Let’s break it down:


Q19. What is the importance of closing a file in Python.
ANS.
      Closing files in Python is an essential practice that helps maintain data integrity,
     prevent resource leaks, and ensure the reliability of your applications.
      By mastering file handling techniques,
     you can write more robust and efficient Python code that effectively manages file resources.

Q20. What is the difference between file.read() and file.readline() in Python.
ANS.
    In Python, the `read()` method is used to read a specified number of characters from a file or input stream,
     while the `readline()` method is used to read a single line from a file or input stream.
     The `read()` method will read the entire content of the file or stream if no argument is provided,
     returning a string.

Q21.What is the logging module in Python used for
ANS.
    Python logging is a module that allows you to track events that occur while your program is running.
    You can use logging to record information about errors,
    warnings, and other events that occur during program execution.
    And logging is a useful tool for debugging, troubleshooting,
     and monitoring your program.

Q22.What is the os module in Python used for in file handling.
ANS.
Python has a built-in os module with methods for interacting with the operating system,
like creating files and directories,
management of files and directories, input, output, environment variables,
process management,

Q23.what are the challenges associated with memory management in python.
ANS.
Memory management is pivotal in programming, not just in Python but across all languages.
It involves handling the temporary data storage needed during program execution, such as variables and literals. As programs expand,
efficient memory management becomes crucial to maintain speed and efficiency, especially in Python,
which powers large-scale applications in Artificial Intelligence and Data Science.

Static Memory Allocation.
  Whenever a new function or class is declared it is very common to have some variable declaration inside them,
 these declarations are associated with the function itself and do not change in the runtime. They occupy a fixed memory size.
  Hence these are stored in the stack area.


Q24 How do you raise an exception manually in Python.
ANS.
As a Python developer you can choose to throw an exception if a condition occurs. To throw (or raise) an exception, use the raise keyword.

Q25.why is it important to use multithreading in certain applications.
ANS.
   Multithreading minimizes the time required for context switching compared to switching between separate processes,
   as threads within the same process share the same memory space and can switch more quickly.
   This results in reduced overhead and improved system responsiveness.
